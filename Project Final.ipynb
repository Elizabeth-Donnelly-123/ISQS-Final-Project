# %%
from IPython.display import Audio
import numpy as np

sample_rate = 44100
notes = {'E4': 329.63, 'D4': 293.66, 'C4': 261.63, 'G4': 392.00}
melody = [
    ('E4', 0.4), ('D4', 0.4), ('C4', 0.4), ('D4', 0.4),
    ('E4', 0.4), ('E4', 0.4), ('E4', 0.6),
    ('D4', 0.4), ('D4', 0.4), ('D4', 0.6),
    ('E4', 0.4), ('G4', 0.4), ('G4', 0.6),
    ('E4', 0.4), ('D4', 0.4), ('C4', 0.4), ('D4', 0.4),
    ('E4', 0.4), ('E4', 0.4), ('E4', 0.4), ('E4', 0.4),
    ('D4', 0.4), ('D4', 0.4), ('E4', 0.4), ('D4', 0.4),
    ('C4', 0.8),
]

song = []
for note, duration in melody:
    t = np.linspace(0, duration, (sample_rate * duration), False)
Audio(song, rate=sample_rate, autoplay=True)

# %%
from IPython.display import Audio
import numpy as np

sample_rate = 44100
notes = {'E4': 329.63, 'D4': 293.66, 'C4': 261.63, 'G4': 392.00}
melody = [
    ('E4', 0.4), ('D4', 0.4), ('C4', 0.4), ('D4', 0.4),
    ('E4', 0.4), ('E4', 0.4), ('E4', 0.6),
    ('D4', 0.4), ('D4', 0.4), ('D4', 0.6),
    ('E4', 0.4), ('G4', 0.4), ('G4', 0.6),
    ('E4', 0.4), ('D4', 0.4), ('C4', 0.4), ('D4', 0.4),
    ('E4', 0.4), ('E4', 0.4), ('E4', 0.4), ('E4', 0.4),
    ('D4', 0.4), ('D4', 0.4), ('E4', 0.4), ('D4', 0.4),
    ('C4', 0.8),
]

song = []
for note, duration in melody:
    t = np.linspace(0, duration, (sample_rate * duration), False)

Audio(song, rate=sample_rate, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 19
#      17 song = []
#      18 for note, duration in melody:
# ---> 19     t = np.linspace(0, duration, (sample_rate * duration), False)
#      21 Audio(song, rate=sample_rate, autoplay=True)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\function_base.py:122, in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#      26 @array_function_dispatch(_linspace_dispatcher)
#      27 def linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None,
#      28              axis=0, *, device=None):
#      29     """
#      30     Return evenly spaced numbers over a specified interval.
#      31
#    (...)    120
#     121     """
# --> 122     num = operator.index(num)
#     123     if num < 0:
#     124         raise ValueError(
# ...

# %%
from IPython.display import Audio
import numpy as np

sample_rate = 44100
notes = {'E4': 329.63, 'D4': 293.66, 'C4': 261.63, 'G4': 392.00}
melody = [
    ('E4', 0.4), ('D4', 0.4), ('C4', 0.4), ('D4', 0.4),
    ('E4', 0.4), ('E4', 0.4), ('E4', 0.6),
    ('D4', 0.4), ('D4', 0.4), ('D4', 0.6),
    ('E4', 0.4), ('G4', 0.4), ('G4', 0.6),
    ('E4', 0.4), ('D4', 0.4), ('C4', 0.4), ('D4', 0.4),
    ('E4', 0.4), ('E4', 0.4), ('E4', 0.4), ('E4', 0.4),
    ('D4', 0.4), ('D4', 0.4), ('E4', 0.4), ('D4', 0.4),
    ('C4', 0.8),
]

song = []
for note, duration in melody:
    t = np.linspace(0, duration, int(sample_rate * duration), False)
    song.extend(tone)

Audio(song, rate=sample_rate, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 20
#      18 for note, duration in melody:
#      19     t = np.linspace(0, duration, int(sample_rate * duration), False)
# ---> 20     song.extend(tone)
#      22 Audio(song, rate=sample_rate, autoplay=True)
#
# NameError: name 'tone' is not defined

# %%
from IPython.display import Audio
import numpy as np

sample_rate = 44100
notes = {'E4': 329.63, 'D4': 293.66, 'C4': 261.63, 'G4': 392.00}
melody = [
    ('E4', 0.4), ('D4', 0.4), ('C4', 0.4), ('D4', 0.4),
    ('E4', 0.4), ('E4', 0.4), ('E4', 0.6),
    ('D4', 0.4), ('D4', 0.4), ('D4', 0.6),
    ('E4', 0.4), ('G4', 0.4), ('G4', 0.6),
    ('E4', 0.4), ('D4', 0.4), ('C4', 0.4), ('D4', 0.4),
    ('E4', 0.4), ('E4', 0.4), ('E4', 0.4), ('E4', 0.4),
    ('D4', 0.4), ('D4', 0.4), ('E4', 0.4), ('D4', 0.4),
    ('C4', 0.8),
]

song = []
for note, duration in melody:
    t = np.linspace(0, duration, int(sample_rate * duration), False)
    tone = np.sin(notes[note] * t * 2 * np.pi)
    song.extend(tone)

Audio(song, rate=sample_rate, autoplay=True)
